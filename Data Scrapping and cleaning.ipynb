# %% [markdown]
# ## importing the  required libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import requests
from bs4 import BeautifulSoup
import re
import time

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity ='all'

# %% [markdown]
# ## saving the url in url variable

# %%
url="https://autoportal.com/usedcars/finder/"

# %% [markdown]
# ## requesting the website

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text)

# %% [markdown]
# ## extracting the data from a website using tags and classes of html and storing it in a list .

# %%
name=[]
info=[]
pri=[]
pagenum=[]
for i in range(1,18):
    start_time=time.time()
    url="https://autoportal.com/usedcars/finder/page-{}/".format(i)
    pag=requests.get(url)
    sou=BeautifulSoup(pag.text)
    for x in sou.find_all("div",class_="cell6 cell-sm"):
        pname=x.find("a",class_="link")
        spec=x.find("div",class_="desc desc-info")
        price=x.find("p",class_="price")
        if pname is None:
            print(np.NaN)
        else:
            print()
            name.append(pname.text)
        if spec is None:
            print(np.NaN)
        else:
            print()
            info.append(spec.text) 
        if price is None:
            print(np.NaN)
        else:
            pri.append(price.text)
        pagenum.append(i)
        print()
    print("page{} is completed in {} seconds".format(i,time.time()-start_time))

# %% [markdown]
# ## creating the dataframe using the extracted data

# %%
df=pd.DataFrame({"name":name,"info":info,"price":pri})

# %% [markdown]
# ## data frame

# %%
df
# Out:
#                                                   name  \
# 0    \n                    Hyundai Grand i10 Magna\...
# 1    \n                    Hyundai Elite i20  Sport...
# 2    \n                    Maruti Suzuki Wagon R VX...
# 3    \n                    Nissan Micra Active XV\n...
# 4    \n                    Hyundai Elite i20  Sport...
# ..                                                 ...
# 505  \n                    Maruti Suzuki Vitara Bre...
# 506  \n                    Maruti Suzuki Alto LXI\n...
# 507  \n                    Hyundai Creta 1.6 CRDI A...
# 508  \n                    Hyundai Eon (2012 - 2019...
# 509  \n                    Maruti Suzuki Wagon R (2...
#
#                                                   info  \
# 0    \n\n                    46,983 km    Petrol  ...
# 1    \n\n                    59,731 km    Diesel  ...
# 2    \n\n                    28,316 km    Petrol  ...
# 3    \n\n                    59,817 km    Petrol  ...
# 4    \n\n                    38,550 km    Petrol  ...
# ..                                                 ...
# 505  \n\n                    15,368 km    Diesel  ...
# 506  \n\n                    45,061 km    Petrol  ...
# 507  \n\n                    72,060 km    Diesel  ...
# 508  \n\n                    28,493 km    Petrol  ...
# 509  \n\n                    45,840 km    CNG    ...
#
#                                price
# 0     \n 3.45 Lakh\n
# 1     \n 5.32 Lakh\n
# 2     \n 4.25 Lakh\n
# 3     \n 3.53 Lakh\n
# 4     \n 6.05 Lakh\n
# ..                               ...
# 505   \n 8.55 Lakh\n
# 506   \n 2.80 Lakh\n
# 507  \n 11.54 Lakh\n
# 508   \n 3.00 Lakh\n
# 509   \n 3.40 Lakh\n
#
# [510 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    510 non-null    object
#  1   info    510 non-null    object
#  2   price   510 non-null    object
# dtypes: object(3)
# memory usage: 12.1+ KB

# %% [markdown]
# ## Data Cleaning

# %%
#replacing the unwanted elements from name column and creating a new column for that
df["Brand Name"]=df["name"].apply(lambda x: x.replace("\n"," ").strip())

# %%
df.head()
# Out:
#                                                 name  \
# 0  \n                    Hyundai Grand i10 Magna\...
# 1  \n                    Hyundai Elite i20  Sport...
# 2  \n                    Maruti Suzuki Wagon R VX...
# 3  \n                    Nissan Micra Active XV\n...
# 4  \n                    Hyundai Elite i20  Sport...
#
#                                                 info  \
# 0  \n\n                    46,983 km    Petrol  ...
# 1  \n\n                    59,731 km    Diesel  ...
# 2  \n\n                    28,316 km    Petrol  ...
# 3  \n\n                    59,817 km    Petrol  ...
# 4  \n\n                    38,550 km    Petrol  ...
#
#                             price                     Brand Name
# 0  \n 3.45 Lakh\n                        Hyundai Grand i10 Magna
# 1  \n 5.32 Lakh\n                  Hyundai Elite i20  Sportz 1.4
# 2  \n 4.25 Lakh\n                      Maruti Suzuki Wagon R VXi
# 3  \n 3.53 Lakh\n                         Nissan Micra Active XV
# 4  \n 6.05 Lakh\n                  Hyundai Elite i20  Sportz 1.2

# %%
#extracting only brand of a car from Brand Name column using regex and creating a new column for that
df["brand"]=df["Brand Name"].apply(lambda x : re.findall("Maruti Suzuki|^\w+",x))

# %%
df["brand"]=df["brand"].apply(lambda x : str(x).replace("[","").replace("]","").replace("'",""))

# %%
df.head()
# Out:
#                                                 name  \
# 0  \n                    Hyundai Grand i10 Magna\...
# 1  \n                    Hyundai Elite i20  Sport...
# 2  \n                    Maruti Suzuki Wagon R VX...
# 3  \n                    Nissan Micra Active XV\n...
# 4  \n                    Hyundai Elite i20  Sport...
#
#                                                 info  \
# 0  \n\n                    46,983 km    Petrol  ...
# 1  \n\n                    59,731 km    Diesel  ...
# 2  \n\n                    28,316 km    Petrol  ...
# 3  \n\n                    59,817 km    Petrol  ...
# 4  \n\n                    38,550 km    Petrol  ...
#
#                             price                     Brand Name  \
# 0  \n 3.45 Lakh\n                        Hyundai Grand i10 Magna
# 1  \n 5.32 Lakh\n                  Hyundai Elite i20  Sportz 1.4
# 2  \n 4.25 Lakh\n                      Maruti Suzuki Wagon R VXi
# 3  \n 3.53 Lakh\n                         Nissan Micra Active XV
# 4  \n 6.05 Lakh\n                  Hyundai Elite i20  Sportz 1.2
#
#            brand
# 0        Hyundai
# 1        Hyundai
# 2  Maruti Suzuki
# 3         Nissan
# 4        Hyundai

# %%
#extracting only model of a car from Brand Name column using regex and creating a new column for that
df["model"]=df["Brand Name"].apply(lambda x: re.findall("Maruti Suzuki\s(\w+)|\w+\s(\w+\s[i20|i10]+)|^\w+\s(\w+)",x))

# %%
df.tail()
# Out:
#                                                   name  \
# 505  \n                    Maruti Suzuki Vitara Bre...
# 506  \n                    Maruti Suzuki Alto LXI\n...
# 507  \n                    Hyundai Creta 1.6 CRDI A...
# 508  \n                    Hyundai Eon (2012 - 2019...
# 509  \n                    Maruti Suzuki Wagon R (2...
#
#                                                   info  \
# 505  \n\n                    15,368 km    Diesel  ...
# 506  \n\n                    45,061 km    Petrol  ...
# 507  \n\n                    72,060 km    Diesel  ...
# 508  \n\n                    28,493 km    Petrol  ...
# 509  \n\n                    45,840 km    CNG    ...
#
#                                price  \
# 505   \n 8.55 Lakh\n
# 506   \n 2.80 Lakh\n
# 507  \n 11.54 Lakh\n
# 508   \n 3.00 Lakh\n
# 509   \n 3.40 Lakh\n
#
#                                     Brand Name          brand            model
# 505           Maruti Suzuki Vitara Brezza ZDI+  Maruti Suzuki   [(Vitara, , )]
# 506                     Maruti Suzuki Alto LXI  Maruti Suzuki     [(Alto, , )]
# 507          Hyundai Creta 1.6 CRDI AT SX Plus        Hyundai  [(, Creta 1, )]
# 508         Hyundai Eon (2012 - 2019) D-Lite +        Hyundai      [(, , Eon)]
# 509  Maruti Suzuki Wagon R (2003-2013) LXI CNG  Maruti Suzuki    [(Wagon, , )]

# %%
#extracting only variant of car from Brand Name column using regex and creating a new column for that
df["var"]=df["Brand Name"].apply(lambda x : re.findall("(Maruti Suzuki\s\w+\s+|\w+\s\w+\s[i20|i10]+\s+|^\w+\s\w+.)(.+)",x))

# %%
df.head()
# Out:
#                                                 name  \
# 0  \n                    Hyundai Grand i10 Magna\...
# 1  \n                    Hyundai Elite i20  Sport...
# 2  \n                    Maruti Suzuki Wagon R VX...
# 3  \n                    Nissan Micra Active XV\n...
# 4  \n                    Hyundai Elite i20  Sport...
#
#                                                 info  \
# 0  \n\n                    46,983 km    Petrol  ...
# 1  \n\n                    59,731 km    Diesel  ...
# 2  \n\n                    28,316 km    Petrol  ...
# 3  \n\n                    59,817 km    Petrol  ...
# 4  \n\n                    38,550 km    Petrol  ...
#
#                             price                     Brand Name  \
# 0  \n 3.45 Lakh\n                        Hyundai Grand i10 Magna
# 1  \n 5.32 Lakh\n                  Hyundai Elite i20  Sportz 1.4
# 2  \n 4.25 Lakh\n                      Maruti Suzuki Wagon R VXi
# 3  \n 3.53 Lakh\n                         Nissan Micra Active XV
# 4  \n 6.05 Lakh\n                  Hyundai Elite i20  Sportz 1.2
#
#            brand              model                                  var
# 0        Hyundai  [(, Grand i10, )]        [(Hyundai Grand i10 , Magna)]
# 1        Hyundai  [(, Elite i20, )]  [(Hyundai Elite i20  , Sportz 1.4)]
# 2  Maruti Suzuki      [(Wagon, , )]      [(Maruti Suzuki Wagon , R VXi)]
# 3         Nissan      [(, , Micra)]         [(Nissan Micra , Active XV)]
# 4        Hyundai  [(, Elite i20, )]  [(Hyundai Elite i20  , Sportz 1.2)]

# %%
y=[]
for n in range(0,len(name)):
    x=df["var"][n][0][1]
    y.append(x)

# %%
df["variantname"]=y

# %%
df["variantname"]=df["variantname"].apply(lambda x: str(x).replace(str(re.findall("(?:\(\d{4}\-\d{4}\))|(?:\(\d{4}\s+\-\s+\d{4}\))",x)).replace("[","").replace("]","").replace("'",""),""))

# %%
#replacing unwanted charecters from model and creating a new column for that
df["newmodel"]=df["model"].apply(lambda x: str(x).replace("]","").replace("[","").replace(",","").replace("(","").replace(")","").replace("'",""))

# %%
df.head()
# Out:
#                                                 name  \
# 0  \n                    Hyundai Grand i10 Magna\...
# 1  \n                    Hyundai Elite i20  Sport...
# 2  \n                    Maruti Suzuki Wagon R VX...
# 3  \n                    Nissan Micra Active XV\n...
# 4  \n                    Hyundai Elite i20  Sport...
#
#                                                 info  \
# 0  \n\n                    46,983 km    Petrol  ...
# 1  \n\n                    59,731 km    Diesel  ...
# 2  \n\n                    28,316 km    Petrol  ...
# 3  \n\n                    59,817 km    Petrol  ...
# 4  \n\n                    38,550 km    Petrol  ...
#
#                             price                     Brand Name  \
# 0  \n 3.45 Lakh\n                        Hyundai Grand i10 Magna
# 1  \n 5.32 Lakh\n                  Hyundai Elite i20  Sportz 1.4
# 2  \n 4.25 Lakh\n                      Maruti Suzuki Wagon R VXi
# 3  \n 3.53 Lakh\n                         Nissan Micra Active XV
# 4  \n 6.05 Lakh\n                  Hyundai Elite i20  Sportz 1.2
#
#            brand              model                                  var  \
# 0        Hyundai  [(, Grand i10, )]        [(Hyundai Grand i10 , Magna)]
# 1        Hyundai  [(, Elite i20, )]  [(Hyundai Elite i20  , Sportz 1.4)]
# 2  Maruti Suzuki      [(Wagon, , )]      [(Maruti Suzuki Wagon , R VXi)]
# 3         Nissan      [(, , Micra)]         [(Nissan Micra , Active XV)]
# 4        Hyundai  [(, Elite i20, )]  [(Hyundai Elite i20  , Sportz 1.2)]
#
#   variantname     newmodel
# 0       Magna   Grand i10
# 1  Sportz 1.4   Elite i20
# 2       R VXi      Wagon
# 3   Active XV        Micra
# 4  Sportz 1.2   Elite i20

# %%
#dropping the unwanted columns 
df.drop("var",axis=1,inplace=True)

# %%
df.head()
# Out:
#                                                 name  \
# 0  \n                    Hyundai Grand i10 Magna\...
# 1  \n                    Hyundai Elite i20  Sport...
# 2  \n                    Maruti Suzuki Wagon R VX...
# 3  \n                    Nissan Micra Active XV\n...
# 4  \n                    Hyundai Elite i20  Sport...
#
#                                                 info  \
# 0  \n\n                    46,983 km    Petrol  ...
# 1  \n\n                    59,731 km    Diesel  ...
# 2  \n\n                    28,316 km    Petrol  ...
# 3  \n\n                    59,817 km    Petrol  ...
# 4  \n\n                    38,550 km    Petrol  ...
#
#                             price                     Brand Name  \
# 0  \n 3.45 Lakh\n                        Hyundai Grand i10 Magna
# 1  \n 5.32 Lakh\n                  Hyundai Elite i20  Sportz 1.4
# 2  \n 4.25 Lakh\n                      Maruti Suzuki Wagon R VXi
# 3  \n 3.53 Lakh\n                         Nissan Micra Active XV
# 4  \n 6.05 Lakh\n                  Hyundai Elite i20  Sportz 1.2
#
#            brand              model variantname     newmodel
# 0        Hyundai  [(, Grand i10, )]       Magna   Grand i10
# 1        Hyundai  [(, Elite i20, )]  Sportz 1.4   Elite i20
# 2  Maruti Suzuki      [(Wagon, , )]       R VXi      Wagon
# 3         Nissan      [(, , Micra)]   Active XV        Micra
# 4        Hyundai  [(, Elite i20, )]  Sportz 1.2   Elite i20

# %%
#dropping the unwanted columns 
df.drop("model",axis=1,inplace=True)

# %%
df.head()
# Out:
#                                                 name  \
# 0  \n                    Hyundai Grand i10 Magna\...
# 1  \n                    Hyundai Elite i20  Sport...
# 2  \n                    Maruti Suzuki Wagon R VX...
# 3  \n                    Nissan Micra Active XV\n...
# 4  \n                    Hyundai Elite i20  Sport...
#
#                                                 info  \
# 0  \n\n                    46,983 km    Petrol  ...
# 1  \n\n                    59,731 km    Diesel  ...
# 2  \n\n                    28,316 km    Petrol  ...
# 3  \n\n                    59,817 km    Petrol  ...
# 4  \n\n                    38,550 km    Petrol  ...
#
#                             price                     Brand Name  \
# 0  \n 3.45 Lakh\n                        Hyundai Grand i10 Magna
# 1  \n 5.32 Lakh\n                  Hyundai Elite i20  Sportz 1.4
# 2  \n 4.25 Lakh\n                      Maruti Suzuki Wagon R VXi
# 3  \n 3.53 Lakh\n                         Nissan Micra Active XV
# 4  \n 6.05 Lakh\n                  Hyundai Elite i20  Sportz 1.2
#
#            brand variantname     newmodel
# 0        Hyundai       Magna   Grand i10
# 1        Hyundai  Sportz 1.4   Elite i20
# 2  Maruti Suzuki       R VXi      Wagon
# 3         Nissan   Active XV        Micra
# 4        Hyundai  Sportz 1.2   Elite i20

# %%
#dropping the unwanted columns 
df.drop("Brand Name",axis=1,inplace=True)

# %%
#replacing the unwanted characters 
df["price"]=df["price"].apply(lambda x : str(x).replace("\n","").replace("Lakh",""))

# %%
#renaming the price coulmn
df.rename(columns={"price":"price(in Lakhs)"},inplace=True)

# %%
#replacing the unwanted characters 
df["info"]=df["info"].apply(lambda x: str(x).replace("\n","").replace("\xa0","").replace("\x95","").replace("'","").replace(",","").strip())

# %%
df.head()
# Out:
#                                                 name  \
# 0  \n                    Hyundai Grand i10 Magna\...
# 1  \n                    Hyundai Elite i20  Sport...
# 2  \n                    Maruti Suzuki Wagon R VX...
# 3  \n                    Nissan Micra Active XV\n...
# 4  \n                    Hyundai Elite i20  Sport...
#
#                                 info         price(in Lakhs)          brand  \
# 0       46983 km  Petrol  Pune  2014   3.45                         Hyundai
# 1  59731 km  Diesel  New Delhi  2015   5.32                         Hyundai
# 2  28316 km  Petrol  Bangalore  2017   4.25                   Maruti Suzuki
# 3  59817 km  Petrol  Bangalore  2014   3.53                          Nissan
# 4  38550 km  Petrol  Bangalore  2015   6.05                         Hyundai
#
#   variantname     newmodel
# 0       Magna   Grand i10
# 1  Sportz 1.4   Elite i20
# 2       R VXi      Wagon
# 3   Active XV        Micra
# 4  Sportz 1.2   Elite i20

# %%
#extracting the city name from info column using regex and creating th new column for that
df["city"]=df["info"].apply(lambda x: re.findall("(\w+)\s+\d",x))

# %%
#replacing the unwanted characters 
df["city"]=df["city"].apply(lambda x: str(x).replace("[","").replace("]","").replace("'",""))

# %%
df.head()
# Out:
#                                                 name  \
# 0  \n                    Hyundai Grand i10 Magna\...
# 1  \n                    Hyundai Elite i20  Sport...
# 2  \n                    Maruti Suzuki Wagon R VX...
# 3  \n                    Nissan Micra Active XV\n...
# 4  \n                    Hyundai Elite i20  Sport...
#
#                                 info         price(in Lakhs)          brand  \
# 0       46983 km  Petrol  Pune  2014   3.45                         Hyundai
# 1  59731 km  Diesel  New Delhi  2015   5.32                         Hyundai
# 2  28316 km  Petrol  Bangalore  2017   4.25                   Maruti Suzuki
# 3  59817 km  Petrol  Bangalore  2014   3.53                          Nissan
# 4  38550 km  Petrol  Bangalore  2015   6.05                         Hyundai
#
#   variantname     newmodel       city
# 0       Magna   Grand i10        Pune
# 1  Sportz 1.4   Elite i20       Delhi
# 2       R VXi      Wagon    Bangalore
# 3   Active XV        Micra  Bangalore
# 4  Sportz 1.2   Elite i20   Bangalore

# %%
#extracting the kms runned from info column using regex and creating th new column for that
df["kms runned"]=df["info"].apply(lambda x: re.findall("^\d+",x))

# %%
#replacing the unwanted characters 
df["kms runned"]=df["kms runned"].apply(lambda x: str(x).replace("[","").replace("]","").replace("'",""))

# %%
df.head()
# Out:
#                                                 name  \
# 0  \n                    Hyundai Grand i10 Magna\...
# 1  \n                    Hyundai Elite i20  Sport...
# 2  \n                    Maruti Suzuki Wagon R VX...
# 3  \n                    Nissan Micra Active XV\n...
# 4  \n                    Hyundai Elite i20  Sport...
#
#                                 info         price(in Lakhs)          brand  \
# 0       46983 km  Petrol  Pune  2014   3.45                         Hyundai
# 1  59731 km  Diesel  New Delhi  2015   5.32                         Hyundai
# 2  28316 km  Petrol  Bangalore  2017   4.25                   Maruti Suzuki
# 3  59817 km  Petrol  Bangalore  2014   3.53                          Nissan
# 4  38550 km  Petrol  Bangalore  2015   6.05                         Hyundai
#
#   variantname     newmodel       city kms runned
# 0       Magna   Grand i10        Pune      46983
# 1  Sportz 1.4   Elite i20       Delhi      59731
# 2       R VXi      Wagon    Bangalore      28316
# 3   Active XV        Micra  Bangalore      59817
# 4  Sportz 1.2   Elite i20   Bangalore      38550

# %%
#extracting the Transmission from info column using regex and creating th new column for that
df["Fuel Type"]=df["info"].apply(lambda x: re.findall("Petrol|Diesel|CNG",x))

# %%
#replacing the unwanted characters 
df["Fuel Type"]=df["Fuel Type"].apply(lambda x: str(x).replace("[","").replace("]","").replace("'","").replace("(","").replace(")","").replace(",",""))

# %%
#extracting the Model Year from info column using regex and creating th new column for that
df["Model Year"]=df["info"].apply(lambda x: re.findall("\d+$",x))

# %%
#replacing the unwanted characters 
df["Model Year"]=df["Model Year"].apply(lambda x: str(x).replace("[","").replace("]","").replace("'",""))

# %%
#droping the unwanted columns
df.drop(["name","info"],axis=1,inplace=True)

# %%
df.head()
# Out:
#           price(in Lakhs)          brand variantname     newmodel       city  \
# 0   3.45                         Hyundai       Magna   Grand i10        Pune
# 1   5.32                         Hyundai  Sportz 1.4   Elite i20       Delhi
# 2   4.25                   Maruti Suzuki       R VXi      Wagon    Bangalore
# 3   3.53                          Nissan   Active XV        Micra  Bangalore
# 4   6.05                         Hyundai  Sportz 1.2   Elite i20   Bangalore
#
#   kms runned Fuel Type Model Year
# 0      46983    Petrol       2014
# 1      59731    Diesel       2015
# 2      28316    Petrol       2017
# 3      59817    Petrol       2014
# 4      38550    Petrol       2015

# %%
#renaming the column
df.rename(columns={"newmodel":"model"},inplace=True)

# %%
df.head()
# Out:
#           price(in Lakhs)          brand variantname        model       city  \
# 0   3.45                         Hyundai       Magna   Grand i10        Pune
# 1   5.32                         Hyundai  Sportz 1.4   Elite i20       Delhi
# 2   4.25                   Maruti Suzuki       R VXi      Wagon    Bangalore
# 3   3.53                          Nissan   Active XV        Micra  Bangalore
# 4   6.05                         Hyundai  Sportz 1.2   Elite i20   Bangalore
#
#   kms runned Fuel Type Model Year
# 0      46983    Petrol       2014
# 1      59731    Diesel       2015
# 2      28316    Petrol       2017
# 3      59817    Petrol       2014
# 4      38550    Petrol       2015

# %%
#arranging the columns in some sort of order
df=df[["brand","model","variantname","Model Year","Fuel Type","kms runned","city","price(in Lakhs)"]]

# %%
#converting the column names as their first letter should be capital
df.columns=map(str.title,df.columns)

# %%
df.head()
# Out:
#            Brand        Model Variantname Model Year Fuel Type Kms Runned  \
# 0        Hyundai   Grand i10        Magna       2014    Petrol      46983
# 1        Hyundai   Elite i20   Sportz 1.4       2015    Diesel      59731
# 2  Maruti Suzuki      Wagon         R VXi       2017    Petrol      28316
# 3         Nissan        Micra   Active XV       2014    Petrol      59817
# 4        Hyundai   Elite i20   Sportz 1.2       2015    Petrol      38550
#
#         City         Price(In Lakhs)
# 0       Pune   3.45
# 1      Delhi   5.32
# 2  Bangalore   4.25
# 3  Bangalore   3.53
# 4  Bangalore   6.05

# %%
df["Model"] =df["Model"].apply(lambda x : x.replace(" ",""))

# %%
df["Fuel Type"] =df["Fuel Type"].apply(lambda x : x.replace(" ",""))

# %%
df.rename(columns={"Kms Runned":"Kms"},inplace=True)

# %%
#converting the data types of columns
df[['Model Year', 'Kms','Price(In Lakhs)']] = df[['Model Year', 'Kms','Price(In Lakhs)']] .apply(pd.to_numeric)
df.dtypes
# Out:
# Brand               object
# Model               object
# Variantname         object
# Model Year           int64
# Fuel Type           object
# Kms                  int64
# City                object
# Price(In Lakhs)    float64
# dtype: object

# %% [markdown]
# ## final structured data

# %%
df.head()
# Out:
#            Brand     Model Variantname  Model Year Fuel Type    Kms  \
# 0        Hyundai  Grandi10       Magna        2014    Petrol  46983
# 1        Hyundai  Elitei20  Sportz 1.4        2015    Diesel  59731
# 2  Maruti Suzuki     Wagon       R VXi        2017    Petrol  28316
# 3         Nissan     Micra   Active XV        2014    Petrol  59817
# 4        Hyundai  Elitei20  Sportz 1.2        2015    Petrol  38550
#
#         City  Price(In Lakhs)
# 0       Pune             3.45
# 1      Delhi             5.32
# 2  Bangalore             4.25
# 3  Bangalore             3.53
# 4  Bangalore             6.05

# %%
#from here i use to run my queries

# %%
df[df["Fuel Type"].str.len()==0].count()
# Out:
# Brand              4
# Model              4
# Variantname        4
# Model Year         4
# Fuel Type          4
# Kms                4
# City               4
# Price(In Lakhs)    4
# dtype: int64

# %%
df["Fuel Type"].replace('',np.nan,inplace=True)

# %%
df.isna().sum()
# Out:
# Brand              0
# Model              0
# Variantname        0
# Model Year         0
# Fuel Type          4
# Kms                0
# City               0
# Price(In Lakhs)    0
# dtype: int64

# %%
df.shape
# Out:
# (510, 8)

# %%
df.dropna(how="any",inplace=True)

# %%
df.shape
# Out:
# (506, 8)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (506, 8)

# %%
df.describe()
# Out:
#         Model Year           Kms  Price(In Lakhs)
# count   506.000000    506.000000       506.000000
# mean   2015.486166  32778.604743         4.915593
# std       1.842514  17360.294201         1.842357
# min    2010.000000   1249.000000         1.370000
# 25%    2014.000000  18088.750000         3.515000
# 50%    2016.000000  31287.000000         4.700000
# 75%    2017.000000  45085.000000         5.900000
# max    2019.000000  82580.000000        15.730000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506 entries, 0 to 509
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            506 non-null    object
#  1   Model            506 non-null    object
#  2   Variantname      506 non-null    object
#  3   Model Year       506 non-null    int64
#  4   Fuel Type        506 non-null    object
#  5   Kms              506 non-null    int64
#  6   City             506 non-null    object
#  7   Price(In Lakhs)  506 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 35.6+ KB

# %%
df.to_csv("Used_car_Price_Analysis.csv")
